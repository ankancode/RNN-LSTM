# %%
import os
import pandas as pd
import numpy as np
import codecs
import string
import nltk
from nltk.tokenize import RegexpTokenizer
import itertools
import unicodedata
from collections import OrderedDict
import re
from collections import Counter
import tensorflow as tf

# %%
# Loading Dataset

loc = '/home/ankan/Projects/RNN-LSTM/enron1'
filelist = os.listdir(loc)

# %%
# Regex for replacing website, clocktime, date, alphanumeric, digits

transformed_labels = OrderedDict([
        (" urlname ",
         '(http[s]?://|www)(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+'),
        (" date ",
         '([1-2][0-9][0-9][0-9])(.|-)(1[0-2]|0[1-9]|[1-9])(.|-)(2[0-9]|3[0-1]|1[0-9]|0[1-9]|[1-9])'),
        (" clocktime ", '(2[0-3]|1[0-9]|0[0-9]|[0-9]):([0-5][0-9])'),
        (" alphanumeric ", '([A-Za-z]+[0-9]|[0-9]+[A-Za-z])[A-Za-z0-9]*'),
        (" digit ", '\d+')
    ])

# %%
# All ascii letters

all_letters = string.ascii_letters + " .,;'"

# %%
# Replacing with Regex

def remove_regex(input_text, regex_pattern, str_replace):
    line = re.sub(regex_pattern, str_replace, input_text)
    return line

# %%
def extract_labels(sentence):
    global labels
    for val, pat in transformed_labels.items():
        sentence = remove_regex(sentence, pat, val)
    return sentence

# %%
# Converting Unicode to Ascii

def unicodeToAscii(sentence):
    return ''.join(
        c for c in unicodedata.normalize('NFD', sentence)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

# %%
# Making email_list and label_list

data = []
label = []
for d in filelist:
    dir_path = os.path.join(loc,d)
    if not os.path.isfile(dir_path):
        files = [f for f in os.listdir(dir_path)]
        for f in files:
            file_path = os.path.join(loc,d,f)
            with codecs.open(file_path, "r",encoding='utf-8', errors='ignore') as fdata:
                email_msg = unicodeToAscii(extract_labels(fdata.read()))
                data.append(email_msg)
                label.append(d)
    else:
        continue
df = pd.DataFrame({'email': data,'label': label})

# %%
df.head(10)
# Out:
#                                                email label
# 0  Subject best prices for impotence drugsone tim...  spam
# 1  Subject can we go over guillermo ' s budget to...  spam
# 2                Subject let the euro make you money  spam
# 3  Subject your investor communiqup  digit get ab...  spam
# 4  Subject hp pavilion v  digit   digit   crt mon...  spam
# 5  Subject paliourg , best medswakey wakey  to sa...  spam
# 6  Subject hi paliourg get all pills . everything...  spam
# 7                               Subject re   digit    spam
# 8  Subject vicodin , via  gra are che . ap here a...  spam
# 9  Subject full stock of all your p  harmacy need...  spam

# %%
df.tail(10)
# Out:
#                                                   email label
# 5162  Subject enron nominations for november  digit ...   ham
# 5163  Subject megan jonessteve  daren ,i interviewed...   ham
# 5164  Subject meter variances  ua  digit  clean  upd...   ham
# 5165  Subject hpl nom for may  digit  ,  digit  see ...   ham
# 5166  Subject cornhuskeri have entered deals into si...   ham
# 5167  Subject hpl nom for april  digit  ,  digit  se...   ham
# 5168  Subject  digit  th noms                      f...   ham
# 5169  Subject nomination  eastrans    digit    digit...   ham
# 5170  Subject eastrans  lst of month nomination  eff...   ham
# 5171  Subject mobil  beaumont  fyifyi  i ' ve entere...   ham

# %%
# Removing punctuation from sentences

tokenizer = RegexpTokenizer(r'\w+')
processed_emails = []
email_words = []
list_of_all_words = []
for index, row in df.iterrows():
    email = row['email'].lower()
    email = tokenizer.tokenize(email)
    email_words.append(email)

# List of all Words

list_of_all_words = list(itertools.chain.from_iterable(email_words))

# %%
# Dictionary of vocabulary and their count

counts = Counter(list_of_all_words)
vocab = sorted(counts, key=counts.get, reverse = True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab)}

# %%
# Number of words in the Vocabulary

len(vocab_to_int)
# Out:
# 65163

# %%
# Sentences in the form of their vocabulary counts

email_integers = []
for each in email_words:
    email_integers.append([vocab_to_int[word] for word in each])

# %%
email_lengths = Counter([len(x) for x in email_integers])

# Zero Length Sentences

print("len_zero: {}".format(email_lengths[0]))

# Maximum Length of the Sentence

print("len_max: {}".format(max(email_lengths)))
# Out:
# len_zero: 0
# len_max: 3559

# %%
# Making each sentences of the length 3559 by left padding with zeros

length = 3559
words = np.zeros((len(email_integers), length), dtype=int)
for i, row in enumerate(email_integers):
    words[i, -len(row):] = np.array(row)[:length]

# %%
# Making labels into binary 0 and 1

labels_int = np.array([1 if each == 'spam' else 0 for each in label])

# %%
# Shuffling Our Dataset

s = np.arange(labels_int.shape[0])
np.random.shuffle(s)
words = words[s]
labels_int = labels_int[s]

# %%
# Splitting into Train, Test and Validation Sets

split_idx = int(len(words)*0.8)
train_x, val_x = words[:split_idx], words[split_idx:]
train_y, val_y = labels_int[:split_idx], labels_int[split_idx:]

test_idx = int(len(val_x)*0.5)
val_x, test_x = val_x[:test_idx], val_x[test_idx:]
val_y, test_y = val_y[:test_idx], val_y[test_idx:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(4137, 3559)
# Validation set: 	(517, 3559)
# Test set: 		(518, 3559)

# %%
# Hyperparameters For RNN_LSTM

lstm_size = 256
lstm_layers = 2
batch_size = 10
learning_rate = 0.001
drop_out = 0.5
epochs = 2

# %%
n_words = len(vocab_to_int)

# Create the graph object

graph = tf.Graph()

# Add nodes to the graph

with graph.as_default():
    inputs_ = tf.placeholder(tf.int32, [None, None], name='inputs')
    labels_ = tf.placeholder(tf.int32, [None, None], name='labels')
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# %%
# Converting Words to Word Embeddings

embed_size = 300 

with graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
# Making our LSTM cell

with graph.as_default():
    def lstm_cell():
        cell = tf.contrib.rnn.LSTMCell(lstm_size, 
                                       initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2),
                                       state_is_tuple=True)
        drop = tf.contrib.rnn.DropoutWrapper(cell, output_keep_prob=keep_prob)
        return drop
    
    stack_cells = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(lstm_layers)])
    
    initial_state = state = stack_cells.zero_state(batch_size, tf.float32)

# %%
with graph.as_default():
    outputs, final_state = tf.nn.dynamic_rnn(stack_cells, embed, initial_state=initial_state)

# %%
# Loss Function and Optimization Function

with graph.as_default():
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    cost = tf.losses.mean_squared_error(labels_, predictions)
    
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
# Evaluation and Accuracy

with graph.as_default():
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Batching

def get_batches(x, y, batch_size=50):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
# Training the RNN_LSTM Model

with graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=graph) as sess:
    sess.run(tf.global_variables_initializer())
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: drop_out,
                    initial_state: state}
            loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)
            
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(stack_cells.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
                    batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
    saver.save(sess, "checkpoints/spam_ham.ckpt")
# Out:
# Epoch: 0/2 Iteration: 5 Train loss: 0.151
# Epoch: 0/2 Iteration: 10 Train loss: 0.244
# Epoch: 0/2 Iteration: 15 Train loss: 0.167
# Epoch: 0/2 Iteration: 20 Train loss: 0.233
# Epoch: 0/2 Iteration: 25 Train loss: 0.208
# Val acc: 0.784
# Epoch: 0/2 Iteration: 30 Train loss: 0.118
# Epoch: 0/2 Iteration: 35 Train loss: 0.167
# Epoch: 0/2 Iteration: 40 Train loss: 0.158
# Epoch: 0/2 Iteration: 45 Train loss: 0.151
# Epoch: 0/2 Iteration: 50 Train loss: 0.125
# Val acc: 0.810
# Epoch: 0/2 Iteration: 55 Train loss: 0.089
# Epoch: 0/2 Iteration: 60 Train loss: 0.136
# Epoch: 0/2 Iteration: 65 Train loss: 0.082
# Epoch: 0/2 Iteration: 70 Train loss: 0.120
# Epoch: 0/2 Iteration: 75 Train loss: 0.215
# Val acc: 0.851
# Epoch: 0/2 Iteration: 80 Train loss: 0.159
# Epoch: 0/2 Iteration: 85 Train loss: 0.048
# Epoch: 0/2 Iteration: 90 Train loss: 0.260
# Epoch: 0/2 Iteration: 95 Train loss: 0.041
# Epoch: 0/2 Iteration: 100 Train loss: 0.020
# Val acc: 0.902
# Epoch: 0/2 Iteration: 105 Train loss: 0.036
# Epoch: 0/2 Iteration: 110 Train loss: 0.020
# Epoch: 0/2 Iteration: 115 Train loss: 0.059
# Epoch: 0/2 Iteration: 120 Train loss: 0.018
# Epoch: 0/2 Iteration: 125 Train loss: 0.120
# Val acc: 0.861
# Epoch: 0/2 Iteration: 130 Train loss: 0.127
# Epoch: 0/2 Iteration: 135 Train loss: 0.001
# Epoch: 0/2 Iteration: 140 Train loss: 0.167
# Epoch: 0/2 Iteration: 145 Train loss: 0.045
# Epoch: 0/2 Iteration: 150 Train loss: 0.002
# Val acc: 0.912
# Epoch: 0/2 Iteration: 155 Train loss: 0.210
# Epoch: 0/2 Iteration: 160 Train loss: 0.260
# Epoch: 0/2 Iteration: 165 Train loss: 0.024
# Epoch: 0/2 Iteration: 170 Train loss: 0.095
# Epoch: 0/2 Iteration: 175 Train loss: 0.070
# Val acc: 0.900
# Epoch: 0/2 Iteration: 180 Train loss: 0.108
# Epoch: 0/2 Iteration: 185 Train loss: 0.106
# Epoch: 0/2 Iteration: 190 Train loss: 0.223
# Epoch: 0/2 Iteration: 195 Train loss: 0.048
# Epoch: 0/2 Iteration: 200 Train loss: 0.021
# Val acc: 0.880
# Epoch: 0/2 Iteration: 205 Train loss: 0.141
# Epoch: 0/2 Iteration: 210 Train loss: 0.123
# Epoch: 0/2 Iteration: 215 Train loss: 0.190
# Epoch: 0/2 Iteration: 220 Train loss: 0.165
# Epoch: 0/2 Iteration: 225 Train loss: 0.373
# Val acc: 0.312
# Epoch: 0/2 Iteration: 230 Train loss: 0.252
# Epoch: 0/2 Iteration: 235 Train loss: 0.380
# Epoch: 0/2 Iteration: 240 Train loss: 0.375
# Epoch: 0/2 Iteration: 245 Train loss: 0.100
# Epoch: 0/2 Iteration: 250 Train loss: 0.174
# Val acc: 0.724
# Epoch: 0/2 Iteration: 255 Train loss: 0.237
# Epoch: 0/2 Iteration: 260 Train loss: 0.125
# Epoch: 0/2 Iteration: 265 Train loss: 0.271
# Epoch: 0/2 Iteration: 270 Train loss: 0.243
# Epoch: 0/2 Iteration: 275 Train loss: 0.292
# Val acc: 0.724
# Epoch: 0/2 Iteration: 280 Train loss: 0.164
# Epoch: 0/2 Iteration: 285 Train loss: 0.247
# Epoch: 0/2 Iteration: 290 Train loss: 0.211
# Epoch: 0/2 Iteration: 295 Train loss: 0.147
# Epoch: 0/2 Iteration: 300 Train loss: 0.201
# Val acc: 0.724
# Epoch: 0/2 Iteration: 305 Train loss: 0.355
# Epoch: 0/2 Iteration: 310 Train loss: 0.272
# Epoch: 0/2 Iteration: 315 Train loss: 0.282
# Epoch: 0/2 Iteration: 320 Train loss: 0.252
# Epoch: 0/2 Iteration: 325 Train loss: 0.299
# Val acc: 0.724
# Epoch: 0/2 Iteration: 330 Train loss: 0.243
# Epoch: 0/2 Iteration: 335 Train loss: 0.256
# Epoch: 0/2 Iteration: 340 Train loss: 0.171
# Epoch: 0/2 Iteration: 345 Train loss: 0.145
# Epoch: 0/2 Iteration: 350 Train loss: 0.226
# Val acc: 0.724
# Epoch: 0/2 Iteration: 355 Train loss: 0.265
# Epoch: 0/2 Iteration: 360 Train loss: 0.219
# Epoch: 0/2 Iteration: 365 Train loss: 0.181
# Epoch: 0/2 Iteration: 370 Train loss: 0.169
# Epoch: 0/2 Iteration: 375 Train loss: 0.219
# Val acc: 0.725
# Epoch: 0/2 Iteration: 380 Train loss: 0.212
# Epoch: 0/2 Iteration: 385 Train loss: 0.235
# Epoch: 0/2 Iteration: 390 Train loss: 0.226
# Epoch: 0/2 Iteration: 395 Train loss: 0.106
# Epoch: 0/2 Iteration: 400 Train loss: 0.140
# Val acc: 0.757
# Epoch: 0/2 Iteration: 405 Train loss: 0.062
# Epoch: 0/2 Iteration: 410 Train loss: 0.181
# Epoch: 1/2 Iteration: 415 Train loss: 0.066
# Epoch: 1/2 Iteration: 420 Train loss: 0.143
# Epoch: 1/2 Iteration: 425 Train loss: 0.098
# Val acc: 0.869
# Epoch: 1/2 Iteration: 430 Train loss: 0.121
# Epoch: 1/2 Iteration: 435 Train loss: 0.097
# Epoch: 1/2 Iteration: 440 Train loss: 0.035
# Epoch: 1/2 Iteration: 445 Train loss: 0.381
# Epoch: 1/2 Iteration: 450 Train loss: 0.101
# Val acc: 0.857
# Epoch: 1/2 Iteration: 455 Train loss: 0.069
# Epoch: 1/2 Iteration: 460 Train loss: 0.062
# Epoch: 1/2 Iteration: 465 Train loss: 0.178
# Epoch: 1/2 Iteration: 470 Train loss: 0.111
# Epoch: 1/2 Iteration: 475 Train loss: 0.020
# Val acc: 0.865
# Epoch: 1/2 Iteration: 480 Train loss: 0.044
# Epoch: 1/2 Iteration: 485 Train loss: 0.007
# Epoch: 1/2 Iteration: 490 Train loss: 0.007
# Epoch: 1/2 Iteration: 495 Train loss: 0.037
# Epoch: 1/2 Iteration: 500 Train loss: 0.043
# Val acc: 0.943
# Epoch: 1/2 Iteration: 505 Train loss: 0.013
# Epoch: 1/2 Iteration: 510 Train loss: 0.004
# Epoch: 1/2 Iteration: 515 Train loss: 0.091
# Epoch: 1/2 Iteration: 520 Train loss: 0.120
# Epoch: 1/2 Iteration: 525 Train loss: 0.101
# Val acc: 0.929
# Epoch: 1/2 Iteration: 530 Train loss: 0.000
# Epoch: 1/2 Iteration: 535 Train loss: 0.098
# Epoch: 1/2 Iteration: 540 Train loss: 0.009
# Epoch: 1/2 Iteration: 545 Train loss: 0.054
# Epoch: 1/2 Iteration: 550 Train loss: 0.125
# Val acc: 0.931
# Epoch: 1/2 Iteration: 555 Train loss: 0.045
# Epoch: 1/2 Iteration: 560 Train loss: 0.039
# Epoch: 1/2 Iteration: 565 Train loss: 0.009
# Epoch: 1/2 Iteration: 570 Train loss: 0.050
# Epoch: 1/2 Iteration: 575 Train loss: 0.000
# Val acc: 0.933
# Epoch: 1/2 Iteration: 580 Train loss: 0.096
# Epoch: 1/2 Iteration: 585 Train loss: 0.065
# Epoch: 1/2 Iteration: 590 Train loss: 0.035
# Epoch: 1/2 Iteration: 595 Train loss: 0.016
# Epoch: 1/2 Iteration: 600 Train loss: 0.045
# Val acc: 0.937
# Epoch: 1/2 Iteration: 605 Train loss: 0.005
# Epoch: 1/2 Iteration: 610 Train loss: 0.101
# Epoch: 1/2 Iteration: 615 Train loss: 0.002
# Epoch: 1/2 Iteration: 620 Train loss: 0.297
# Epoch: 1/2 Iteration: 625 Train loss: 0.394
# Val acc: 0.755
# Epoch: 1/2 Iteration: 630 Train loss: 0.481
# Epoch: 1/2 Iteration: 635 Train loss: 0.113
# Epoch: 1/2 Iteration: 640 Train loss: 0.169
# Epoch: 1/2 Iteration: 645 Train loss: 0.181
# Epoch: 1/2 Iteration: 650 Train loss: 0.179
# Val acc: 0.806
# Epoch: 1/2 Iteration: 655 Train loss: 0.161
# Epoch: 1/2 Iteration: 660 Train loss: 0.165
# Epoch: 1/2 Iteration: 665 Train loss: 0.063
# Epoch: 1/2 Iteration: 670 Train loss: 0.123
# Epoch: 1/2 Iteration: 675 Train loss: 0.185
# Val acc: 0.839
# Epoch: 1/2 Iteration: 680 Train loss: 0.103
# Epoch: 1/2 Iteration: 685 Train loss: 0.441
# Epoch: 1/2 Iteration: 690 Train loss: 0.029
# Epoch: 1/2 Iteration: 695 Train loss: 0.140
# Epoch: 1/2 Iteration: 700 Train loss: 0.202
# Val acc: 0.916
# Epoch: 1/2 Iteration: 705 Train loss: 0.001
# Epoch: 1/2 Iteration: 710 Train loss: 0.002
# Epoch: 1/2 Iteration: 715 Train loss: 0.000
# Epoch: 1/2 Iteration: 720 Train loss: 0.074
# Epoch: 1/2 Iteration: 725 Train loss: 0.011
# Val acc: 0.947
# Epoch: 1/2 Iteration: 730 Train loss: 0.130
# Epoch: 1/2 Iteration: 735 Train loss: 0.056
# Epoch: 1/2 Iteration: 740 Train loss: 0.090
# Epoch: 1/2 Iteration: 745 Train loss: 0.002
# Epoch: 1/2 Iteration: 750 Train loss: 0.005
# Val acc: 0.925
# Epoch: 1/2 Iteration: 755 Train loss: 0.006
# Epoch: 1/2 Iteration: 760 Train loss: 0.020
# Epoch: 1/2 Iteration: 765 Train loss: 0.003
# Epoch: 1/2 Iteration: 770 Train loss: 0.185
# Epoch: 1/2 Iteration: 775 Train loss: 0.011
# Val acc: 0.947
# Epoch: 1/2 Iteration: 780 Train loss: 0.089
# Epoch: 1/2 Iteration: 785 Train loss: 0.086
# Epoch: 1/2 Iteration: 790 Train loss: 0.002
# Epoch: 1/2 Iteration: 795 Train loss: 0.011
# Epoch: 1/2 Iteration: 800 Train loss: 0.136
# Val acc: 0.949
# Epoch: 1/2 Iteration: 805 Train loss: 0.001
# Epoch: 1/2 Iteration: 810 Train loss: 0.028
# Epoch: 1/2 Iteration: 815 Train loss: 0.002
# Epoch: 1/2 Iteration: 820 Train loss: 0.001
# Epoch: 1/2 Iteration: 825 Train loss: 0.004
# Val acc: 0.959

# %%
# Testing the RNN_LSTM Model

test_acc = []
with tf.Session(graph=graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    test_state = sess.run(stack_cells.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints_try/spam_ham.ckpt
# Test accuracy: 0.959
